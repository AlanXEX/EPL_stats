# %% [markdown]
# # Analysis of English Premier League Statistics
# ## Introduction
# I choose an England Premier League home/away games stats from 2006 to 2017. I have choosen this topic, because it is very interesting how English teams could play home and away games. It is hard to play away games, because there are no your fans and you have travelled some road and so on. Football is very interesting game, and each result has consequences on a table and how the game goes in next week. Also, it is very important what is going on inside the team, because it can affect on players' mood, players' efficiency and their readiness for matches. There is the data in two separate tables with the results of the Premier League football matches taken in the period from 2006 to 2018. In both tables ‘teams’ is taken as a primary key so the data from the tables is connected to the ‘teams’. In the first table, which is called results.csv, the first two columns include names of the home teams and away teams, i.e. football teams that played in a certain match. Next two columns present the information about the number of goals scored separately by the home team and the away team. The fifth column is called ‘result’ and includes information about the winner of a certain match - ‘H’ for home team, ‘A’ for away team and ‘D’ for draw. Finally, the last column presents the season, in other words period, in which the match was taken. The second table - stats.cvs, represents data about the results for a certain football team. The first column includes names of each team, and the next three columns represent the data about the number of their wins, losses and total goals scored. The fifth and sixth columns include data with the number of received in total yellow and red cards respectively. The next three columns demonstrate the number of total shots, shots on target and shots that hit bar/post/woodwork. The following six columns represent the total number of goals from headers, goals from penalties, goals from free-kicks, goals from inside and outside the box and goals from counter attacks. Then there is a column that includes the total number of offsides, and the following column represents the number of clean sheets. Finally, the last column demonstrates the data of total goals conceded.
# ## Data description and objectives
#
# I want to research 5 main questions for me.
# + How the given teams realized their best chances and how much it let to scored goals and with saved penalties information?
# + How many Red Cards and Yellow Cards get players of given teams during all the time?
# + In which seasons the given teams in the table missed their big chances to score goals?
# + How many wins got teams during given seasons?
# + How many red cards got teams during given seasons?
#
# Official football data organised and formatted in csv files ready for download is quite hard to come by. Stats providers are hesitant to release their data to anyone and everyone, even if it's for academic purposes. That was my exact dilemma which prompted me to scrape and extract it myself. Now that it's at your disposal, have fun with it.
# The data was acquired from the Premier League website and is representative of seasons 2006/2007 to 2017/2018. Visit both sets to get a detailed description of what each entails.
#
# ## Data manipulation

# %%
import numpy as np
import pandas as pd
pd1=pd.read_csv('results.csv')
pd1.notnull() #checking for missing values(all values are true)
# Out:
#       home_team  away_team  home_goals  away_goals  result  season
# 0          True       True        True        True    True    True
# 1          True       True        True        True    True    True
# 2          True       True        True        True    True    True
# 3          True       True        True        True    True    True
# 4          True       True        True        True    True    True
# ...         ...        ...         ...         ...     ...     ...
# 4555       True       True        True        True    True    True
# 4556       True       True        True        True    True    True
# 4557       True       True        True        True    True    True
# 4558       True       True        True        True    True    True
# 4559       True       True        True        True    True    True
#
# [4560 rows x 6 columns]

# %%
pd2=pd1.rename(columns={'home_team':'HomeTeam'})# changing the name of column
pd2.sort_values(by='away_goals',ascending=False) # sorting by top away goals
# Out:
#                HomeTeam          away_team  home_goals  away_goals result  \
# 4173          Hull City  Tottenham Hotspur         1.0         7.0      A
# 1986  Manchester United    Manchester City         1.0         6.0      A
# 4169     Leicester City  Tottenham Hotspur         1.0         6.0      A
# 4225            Watford    Manchester City         0.0         6.0      A
# 2229       Norwich City    Manchester City         1.0         6.0      A
# ...                 ...                ...         ...         ...    ...
# 1290    Birmingham City    West Ham United         1.0         0.0      H
# 1294          Hull City   Blackburn Rovers         0.0         0.0      D
# 3144    West Ham United        Aston Villa         0.0         0.0      D
# 3143        Southampton     Leicester City         2.0         0.0      H
# 2280            Arsenal         Sunderland         0.0         0.0      D
#
#          season
# 4173  2016-2017
# 1986  2011-2012
# 4169  2016-2017
# ...

# %%
import numpy as np
import pandas as pd
pd30=pd.read_csv('stats.csv')
pd30
# Out:
#                      team  wins  losses  goals  total_yel_card  \
# 0       Manchester United  28.0     5.0   83.0            60.0
# 1                 Chelsea  24.0     3.0   64.0            62.0
# 2               Liverpool  20.0    10.0   57.0            44.0
# 3                 Arsenal  19.0     8.0   63.0            59.0
# 4       Tottenham Hotspur  17.0    12.0   57.0            48.0
# ..                    ...   ...     ...    ...             ...
# 235     Huddersfield Town   9.0    19.0   28.0            62.0
# 236          Swansea City   8.0    21.0   28.0            51.0
# 237           Southampton   7.0    16.0   37.0            63.0
# 238            Stoke City   7.0    19.0   35.0            62.0
# 239  West Bromwich Albion   6.0    19.0   31.0            73.0
#
#      total_red_card  total_scoring_att  ontarget_scoring_att  hit_woodwork  \
# 0               1.0              698.0                 256.0          21.0
# ...

# %%
Coloumn_List = ["team","wins","losses"] 
pd31=pd.read_csv('stats.csv',usecols=Coloumn_List)
pd31.head(5) # top 5 teams with most wins
# Out:
#                 team  wins  losses
# 0  Manchester United  28.0     5.0
# 1            Chelsea  24.0     3.0
# 2          Liverpool  20.0    10.0
# 3            Arsenal  19.0     8.0
# 4  Tottenham Hotspur  17.0    12.0

# %%
Coloumn_List = ["team","goals","ontarget_scoring_att"] 
pd32=pd.read_csv('stats.csv',usecols=Coloumn_List)

# %%
pd30.dropna() # deleted rows with null values
# Out:
#                      team  wins  losses  goals  total_yel_card  \
# 80      Manchester United  23.0     4.0   78.0            56.0
# 81                Chelsea  21.0     9.0   69.0            59.0
# 82        Manchester City  21.0     9.0   60.0            71.0
# 83                Arsenal  19.0     8.0   72.0            65.0
# 84              Liverpool  17.0    14.0   59.0            63.0
# ..                    ...   ...     ...    ...             ...
# 235     Huddersfield Town   9.0    19.0   28.0            62.0
# 236          Swansea City   8.0    21.0   28.0            51.0
# 237           Southampton   7.0    16.0   37.0            63.0
# 238            Stoke City   7.0    19.0   35.0            62.0
# 239  West Bromwich Albion   6.0    19.0   31.0            73.0
#
#      total_red_card  total_scoring_att  ontarget_scoring_att  hit_woodwork  \
# 80              3.0              618.0                 212.0          15.0
# ...

# %% [markdown]
# ### Further Data Preparation and Visualization

# %%
# First research question: Is it harder to play away, or at home? 
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt

# %%
Coloumn_List = ["team","goals","ontarget_scoring_att","penalty_save"] 
pd29=pd.read_csv('stats.csv',usecols=Coloumn_List)
pd29.head()
# Out:
#                 team  goals  ontarget_scoring_att  penalty_save
# 0  Manchester United   83.0                 256.0           2.0
# 1            Chelsea   64.0                 216.0           1.0
# 2          Liverpool   57.0                 214.0           0.0
# 3            Arsenal   63.0                 226.0           0.0
# 4  Tottenham Hotspur   57.0                 184.0           0.0

# %%
pd29.describe()
# Out:
#             goals  ontarget_scoring_att  penalty_save
# count  240.000000            240.000000    240.000000
# mean    51.062500            168.116667      0.837500
# std     16.203474             38.748882      0.947718
# min     20.000000             94.000000      0.000000
# 25%     40.000000            140.000000      0.000000
# 50%     47.000000            158.500000      1.000000
# 75%     61.000000            194.250000      1.000000
# max    106.000000            288.000000      5.000000

# %%
pd29.shape
# Out:
# (240, 4)

# %%
x=sns.lmplot(data=pd29,x="ontarget_scoring_att",y="goals",hue="penalty_save")
x.fig.suptitle('Attempts to score and scored goals with saved penalties',fontsize=15,y=1.1)
# Out:
# Text(0.5, 1.1, 'Attempts to score and scored goals with saved penalties')

# %%
# The graph shows goals toward scoring attempt with a different amount of penalty saves.According to graph, 3 penalty saves were the most rare.

# %%
Coloumn_List = ["team","total_yel_card","total_red_card"] 
pd33=pd.read_csv('stats.csv',usecols=Coloumn_List)
pd33.head()
# Out:
#                 team  total_yel_card  total_red_card
# 0  Manchester United            60.0             1.0
# 1            Chelsea            62.0             4.0
# 2          Liverpool            44.0             0.0
# 3            Arsenal            59.0             3.0
# 4  Tottenham Hotspur            48.0             3.0

# %%
pd33.describe()
# Out:
#        total_yel_card  total_red_card
# count      240.000000      240.000000
# mean        61.079167        2.862500
# std         10.078249        1.802442
# min         38.000000        0.000000
# 25%         54.000000        1.000000
# 50%         60.500000        3.000000
# 75%         67.000000        4.000000
# max         94.000000        9.000000

# %%
pd33.shape
# Out:
# (240, 3)

# %%
x=sns.catplot(data=pd33.head(10),kind="bar",ci=0)
x.fig.suptitle('Total red and yellow cards during all seasons',fontsize=15,y=1.1)
# Out:
# Text(0.5, 1.1, 'Total red and yellow cards during all seasons')

# %%
# In the given bar graph, we can see the total amount of red and yellow cards in all seasons in the table.The number of yellow cards significantly exceeds the number of red cards by 20 times

# %%
Coloumn_List = ["team","big_chance_missed","season"] 
pd34=pd.read_csv('stats.csv',usecols=Coloumn_List)
pd34.dropna()
pd34.head()
# Out:
#                 team  big_chance_missed     season
# 0  Manchester United                NaN  2006-2007
# 1            Chelsea                NaN  2006-2007
# 2          Liverpool                NaN  2006-2007
# 3            Arsenal                NaN  2006-2007
# 4  Tottenham Hotspur                NaN  2006-2007

# %%
pd34.describe()
# Out:
#        big_chance_missed
# count         160.000000
# mean           39.200000
# std            13.391915
# min            18.000000
# 25%            30.000000
# 50%            37.000000
# 75%            44.250000
# max            88.000000

# %%
pd34.shape
# Out:
# (240, 3)

# %%
x=sns.catplot(data=pd34.dropna(),kind="bar",y="season",x="big_chance_missed",ci=0)
x.fig.suptitle('Missed chances during 2010-11 and 2017-18 seasons',fontsize=15,y=1.1)
# Out:
# Text(0.5, 1.1, 'Missed chances during 2010-11 and 2017-18 seasons')

# %%
# This graph shows us the missed chances to score goals during 8 seasons. Missed chances vary from 30 and more than 40.The most unlucky moments happened in season 2010-2011.

# %%
Coloumn_List = ["team","wins","season"] 
pd35=pd.read_csv('stats.csv',usecols=Coloumn_List)
pd35.dropna()
pd35.head()
# Out:
#                 team  wins     season
# 0  Manchester United  28.0  2006-2007
# 1            Chelsea  24.0  2006-2007
# 2          Liverpool  20.0  2006-2007
# 3            Arsenal  19.0  2006-2007
# 4  Tottenham Hotspur  17.0  2006-2007

# %%
pd35.describe()
# Out:
#              wins
# count  240.000000
# mean    14.150000
# std      6.022482
# min      1.000000
# 25%     10.000000
# 50%     12.000000
# 75%     18.000000
# max     32.000000

# %%
pd35.shape
# Out:
# (240, 3)

# %%
x=sns.catplot(data=pd35,x="wins",y="team",hue="season")
x.fig.suptitle('Win of Teams during 2006-07 and 2017-18 season',fontsize=15,y=1.1)
# Out:
# Text(0.5, 1.1, 'Win of Teams during 2006-07 and 2017-18 season')

# %%
# In the given grpah, we can find information about team's winnig statistics during 2006-07 and 2017-18 seasons.The graph shows that Manchester City has most wins.

# %%
Coloumn_List = ["team","total_red_card","season"] 
pd36=pd.read_csv('stats.csv',usecols=Coloumn_List)
pd36.dropna()
pd36.head()
# Out:
#                 team  total_red_card     season
# 0  Manchester United             1.0  2006-2007
# 1            Chelsea             4.0  2006-2007
# 2          Liverpool             0.0  2006-2007
# 3            Arsenal             3.0  2006-2007
# 4  Tottenham Hotspur             3.0  2006-2007

# %%
pd36.describe()
# Out:
#        total_red_card
# count      240.000000
# mean         2.862500
# std          1.802442
# min          0.000000
# 25%          1.000000
# 50%          3.000000
# 75%          4.000000
# max          9.000000

# %%
pd36.shape
# Out:
# (240, 3)

# %%
x=sns.catplot(data=pd36,x="total_red_card",y="team",hue="season")
x.fig.suptitle('Win of Teams during 2006-07 and 2017-18 season',fontsize=15,y=1.1)
# Out:
# Text(0.5, 1.1, 'Win of Teams during 2006-07 and 2017-18 season')

# %%
# The given graph shows how much red cards got teams during given seasons. We can see that Queens Park Rangers and Sunderland got high amount of numbers in the graph

# %% [markdown]
# # Conclusion
# In this poroject I analyzed England Premier League during years 2006 and 2007. Also, I provided 5 reaserch questions and provided graphs for each one. This has been a fun exercise to go through. I enjoyed it a lot and was glad to see some premier league data in one place. It is always had to get hands on premier league data or any other league’s data. There were some obvious things in the data and a few that i did not expect. I look forward to your comments and input about whats above.
